# %% [markdown]
# # End-of-Module Assessment 2

# %% [markdown]
# ## Instructions
#
# Please read and follow these instructions and specifications carefully.
#
# 1. This test is available from now until August 6 (Friday), 11:59 PM.
# 2. This test covers Module 5, which is about data analysis using libraries. However, you will need fundamental skills from Modules 2 to 4 to do this test properly.
# 3. This test is by project group.
# 4. You are allowed to use the specified non-standard libraries for this test: `pandas`, `numpy`, and `matplotlib`. You are allowed to use any standard library for this test.
# 5. Answers to problems that are hard-coded, done in another program such as Excel, or go against the learning outcomes in any other manner will be given no credit. If you are unsure whether your approach to a problem goes against the learning outcomes, ask.
# 6. We reserve the right to scrutinize answers to problems that significantly go against the philosophy of a library. For example, if you answer a Pandas item mostly using vanilla Python loops and data structures, you go against the philosophy of Pandas (and NumPy), which is to _vectorize_ your operations as much as you can. We reserve the right to scrutinize your answer accordingly.
# 7. You are encouraged to use only the provided code cell for each number. However, if you _need_ more cells, you may add them. If you do add more cells, make sure to label them very clearly. Code cells that are not clearly labelled will not be checked.
# 8. If you are asked to output files, please write them all to the `output` folder. If your kit does not have an `output` folder, you may make one.
#
# Submission instructions for normal (i.e., not cross-section) groups:
# 1. Assign a group leader. The leader is who will submit the assessment.
# 2. The leader must create a NEW GitHub repository. This repository is what they will submit to the Canvas assignment to indicate that the group has submitted. They should name this repository SECTION-GROUPNUM-EOMA2 (e.g., A-5-EOMA2).
# 3. The leader must upload the contents of this folder to the repository. This includes the EOMA2.ipynb file, the output folder, and all section folders.
# 4. To officially submit the assignment, the group leader must upload the link to the GitHub repository and ALL GROUP MEMBERS' COAs to the Canvas assignment.
#
# Submission instructions for cross-section groups:
# 1. Assign a group leader. The leader is who will create the GitHub repository, and they are who will add the required files to the GitHub repository.
# 2. The leader must create a NEW GitHub repository. They should name this repository GROUPNAME-EOMA2 (e.g., CS1-EOMA2).
# 3. The leader must upload the contents of this folder to the repository. This includes the EOMA2.ipynb file, the output folder, and all section folders.
# 4. Since your group is split across sections, your group must choose one member per represented section to submit the exact same file kit to their respective section's Canvas assignment. For example, if all sections (A, G, and H) are represented in your group, choose one person per section (i.e., 3 people) to submit your EOMA2 submission to their respective section's Canvas assignment. If only two sections are represented, then only 2 submissions (i.e., one per represented section, so in this case 2) must be submitted. Please note that we will quite literally not give a grade to students in cross-section groups who are not represented by a submission for their section.

# %% [markdown]
# ## Section 1: Financial Data (75 points)

# %% [markdown]
# ### Context
#
# You are a freelance data consultant. You were hired by a firm that sells historical data on the prices of cryptocurrencies in bulk to aspiring quantitative analysts. However, a freak flood in their data center corrupted their databases, causing their data to be damaged. It is now up to you to fix their data and to polish it into a form that is presentable and acceptable to one of their biggest clients.
#
# The client firm provided you with six sample corrupted files:
# 1. `./section1/CORRUPTED-AC-ALLDAYS-07-2021.csv`
# 2. `./section1/CORRUPTED-CC-ALLDAYS-07-2021.csv`
# 3. `./section1/CORRUPTED-DC-ALLDAYS-07-2021.csv`
# 4. `./section1/CORRUPTED-EC2-ALLDAYS-07-2021.csv`
# 5. `./section1/CORRUPTED-NC-ALLDAYS-07-2021.csv`
# 6. `./section1/CORRUPTED-SHC-ALLDAYS-07-2021.csv`
#
# Each of these sample files represents the price history of a cryptocurrency from January 1, 2015 to December 31, 2019. Remember that these are just _sample_ files and that the true database is many thousands of files large. (The client firm declined to share their entire database for information security reasons.) As such, **you are expected to perform these operations in Pandas instead of vanilla Python to increase the efficiency of your scripts when they are eventually deployed to their servers**.
#
# You have surveyed the data a little, and it is clear to you that all of the data sets suffer from the same defects. (In other words: the files are all damaged _in the same way_.) It is also clear to you that you will be working with dates. You think to yourself: maybe there's a library for this.
#
# The client did not provide any sample output.

# %% [markdown]
# ### 1.1
#
# The client wants you to repair each of the damaged files by following these rules:
# 1. Some of the date values are missing. They want you to ensure that all dates have a row in the repaired files, and they want you to fill the price value of the repaired rows with the most recent valid price value. If there is no most recent valid price value, use the next valid price value.
# 2. The clients also want you to remove rows with dates that are on weekends. They acknowledge that this is strange given that cryptocurrencies are traded nonstop, but they explain that it is because their own clients come from a banking background and that their clients specifically requested it.
#
# Save each of the repaired files as `./output/REPAIRED-{CODE}-ALLDAYS-07-2021.csv`. So, for example, `./section1/CORRUPTED-AC-ALLDAYS-07-2021.csv` will be repaired and saved as `./output/REPAIRED-AC-ALLDAYS-07-2021.csv`.
#
# Do not include the dataframe index when saving the dataframes to csv.

# %%
# CODE CELL
import pandas as pd

# CODE START

# CODE END

# %% [markdown]
# ### 1.2
#
# The client also wants you to _aggregate_ the data so that it is easier to make it portable and so that it is easier to create chart thumbnails from the data. They want you to follow these rules:
# 1. They want you to use the _repaired files_ as the basis data for this task.
# 2. They want you to group the data by _month_ and for the price to be the average of all of the data entries that fall within the respective month. In other words, each row should have two columns: `month` and `average_price`. `month` should be a string formatted as {YEAR}-{MONTHNUM} (e.g., 2015-1 for January 2015), and `average_price` should simply be the float value of the average price of all data entries that belong to that month.
#
# Save each of the transformed files as `./output/AGGREGATED-{CODE}-ALLDAYS-07-2021.csv`. So, for example, `./output/REPAIRED-AC-ALLDAYS-07-2021.csv` will be aggregated and saved as `./output/AGGREGATED-AC-ALLDAYS-07-2021.csv`
#
# Do not include the dataframe index when saving the dataframes to csv.

# %%
# CODE CELL
import pandas as pd

# CODE START

# CODE END

# %% [markdown]
# ### 1.3
#
# Finally, the client wants you to generate charts that they can use as thumbnails for their data products. They want you to follow these rules:
# 1. They want you to use the _aggregated files_ as the basis data for this task.
# 2. They want you to visualize the aggregated data as a line chart. Use the `month` column as the x-axis and the `average_price` column as the y-axis.
#
# Save each of the generated charts as `./output/CHART-{CODE}.png`. So, for example, `./output/AGGREGATED-AC-ALLDAYS-07-2021.csv` will be charted and saved as `./output/CHART-AC.png`.

# %%
# CODE CELL
import pandas as pd
import matplotlib.pyplot as plt

# CODE START

# CODE END

# This is a sample chart. Delete this when you run your cell. 
# Make yours look nicer, but this is generally the backbone of what you should output.
from IPython.display import Image
Image(filename='./section1/sample-basic-chart.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f3e08d407885> in <module>
#      10 # Make yours look nicer, but this is generally the backbone of what you should output.
#      11 from IPython.display import Image
# ---> 12 Image(filename='./section1/sample-basic-chart.png')
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1222         self.retina = retina
#    1223         self.unconfined = unconfined
# -> 1224         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1225                 metadata=metadata)
#    1226
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, metadata)
#     628             self.metadata = {}
#     629
# --> 630         self.reload()
#     631         self._check_data()
#     632
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
#    1254         """Reload the raw data from file or URL."""
#    1255         if self.embed:
# -> 1256             super(Image,self).reload()
#    1257             if self.retina:
#    1258                 self._retina_shape()
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
#     653         """Reload the raw data from file or URL."""
#     654         if self.filename is not None:
# --> 655             with open(self.filename, self._read_flags) as f:
#     656                 self.data = f.read()
#     657         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: './section1/sample-basic-chart.png'

# %% [markdown]
# ## Section 2: Cleaning Marketing Data (75 points)

# %% [markdown]
# ### Context
#
# You are a freelance data consultant. You were hired by a marketing firm that collects customer data for their clients, which are big fast-moving-consumer-goods (FMCG) firms. Your client, the marketing firm, currently handles their operations through a "multi-channel" approach. (To grossly oversimplify, a multi-channel approach to marketing means that a brand can interact with customers across more than one channel). However, they would like to upgrade their system to use an "omni-channel" approach. (An omni-channel approach means that a customer can be recognized across multiple channels. This is important because you will be able to personalize their experience better.)
#
# Your client currently has three main data sets:
# 1. Manual interaction (`./section2/raw-manual.csv`)
# 2. Website interaction (`./section2/raw-website.csv`)
# 3. Email interaction (`./section2/raw-email.csv`)
#
# They task you with cleaning and merging their data to help them establish their omni-channel capabilities.
#
# Again, you are to use Pandas for this, because your client's real databases are much, much bigger than these samples.

# %% [markdown]
# ### 2.1
#
# Your client first asks you to clean up their data. They want their data to follow these rules:
# 1. Emails must not have any capital letters.
# 2. Mobile numbers must be formatted as `+63XXXXXXXXXX` (e.g., +639174005892).
# 3. All the fields (fname, lname, email, and mobile) must be filled.
# 4. The fields must only contain data relevant to them; they must not contain data that does not belong in their column.
#
# You have surveyed the data a little, and you have determined that though the data is dirty, it at least adheres to the following patterns:
# 1. All of the emails adhere to the email standard at https://emailregex.com/. (That's a hint.)
# 2. There are only 4 different "patterns" under the `mobile` columns per data set. (An empty field is not one of these 4 patterns).
# 3. The manual data set appears to have sometimes merged the `email` value and the `mobile` value into the `email` column and left the `mobile` column empty. The mobile value in these defective columns may be any one of the 4 different "patterns" that mobile numbers follow.
#
# Perform this cleanup on each of the three raw data sets.
#
# Save the cleaned data sets as `./output/cleaned-{dataset_name}.csv`. So, for example, `./section2/raw-manual.csv` will be cleaned and saved as `./output/cleaned-manual.csv`.
#
# Do not include the dataframe index in the output csv.

# %%
import pandas as pd
import re 

# Download files: raw-email.csv, raw-manual.csv, raw-website.csv
# Load csv files to dataframe
# Assign file name to filename_1, filename_2, filename_3 variables
filename_raw_email = 'C:\\Users\\University Account\\Desktop\\End of Module Assessment 2\\section2\\raw-email.csv'
filename_raw_manual = 'C:\\Users\\University Account\\Desktop\\End of Module Assessment 2\\section2\\raw-manual.csv'
filename_raw_website = 'C:\\Users\\University Account\\Desktop\\End of Module Assessment 2\\section2\\raw-website.csv'

df_email = pd.read_csv(filename_raw_email)
df_manual = pd.read_csv(filename_raw_manual)
df_website = pd.read_csv(filename_raw_website)

# 1. Emails must NOT have any capital letters. (Problem: Some emails have modile numbers!)
# df_email       
df_email['email'] = df_email['email'].str.lower() # All characters are in lowercase.
list_of_all_cleaned_email_addresses_in_df_email = [] # Create a new list entitled list_of_all_cleaned_email_addresses_in_df_email
list_of_all_mobile_numbers_in_df_email = [] # Create a new list entitled list_of_all_mobile_numbers_in_df_email

for index_number_df_email, each_email_in_df_email in enumerate(df_email['email']): # Use enumerate to get the index numbers of each_email_in_df_email
    if ' / ' not in df_email['email'][index_number_df_email]: # If the cellphone number was not provided with the email address...
        df_email_cleaned_email_address = df_email['email'][index_number_df_email] # The email address will remain as is
        list_of_all_cleaned_email_addresses_in_df_email.append(df_email_cleaned_email_address) # Append the email address to the list_of_all_cleaned_email_addresses_in_df_email
    elif ' / ' in df_email['email'][index_number_df_email]: # If the delimiter (' / ') is present in the email address...
        df_email_cleaned_email_address = re.split(r' / ', df_email['email'][index_number_df_email])[0] # Get the email string with an index of 0
        df_email_mobile_number = re.split(r' / ', df_email['email'][index_number_df_email])[1] # Get the phone number with an index of 1
        list_of_all_cleaned_email_addresses_in_df_email.append(df_email_cleaned_email_address) # Append the cleaned email address to the list_of_all_cleaned_email_addresses_in_df_email
        list_of_all_mobile_numbers_in_df_email.append(df_email_mobile_number) # Append the mobile numbers to the list_of_all_mobile_numbers_in_df_email

# df_manual        
df_manual['email'] = df_manual['email'].str.lower() # All characters are in lowercase.
list_of_all_cleaned_email_addresses_in_df_manual = [] # Create a new list entitled list_of_all_cleaned_email_addresses_in_df_manual
list_of_all_mobile_numbers_in_df_manual = [] # Create a new list entitled list_of_all_mobile_numbers_in_df_manual

for index_number_df_manual, each_email_in_df_manual in enumerate(df_manual['email']): # Use enumerate to get the index numbers of each_email_in_df_manual
    if ' / ' not in df_manual['email'][index_number_df_manual]: # If the cellphone number was not provided with the email address...
        df_manual_cleaned_email_address = df_manual['email'][index_number_df_manual] # The email address will remain as is
        list_of_all_cleaned_email_addresses_in_df_manual.append(df_manual_cleaned_email_address) # Append the email address to the list_of_all_cleaned_email_addresses_in_df_manual
    elif ' / ' in df_manual['email'][index_number_df_manual]: # If the delimiter (' / ') is present in the email address...
        df_manual_cleaned_email_address = re.split(r' / ', df_manual['email'][index_number_df_manual])[0] # Get the email string with an index of 0
        df_manual_mobile_number = re.split(r' / ', df_manual['email'][index_number_df_manual])[1] # Get the phone number with an index of 1
        list_of_all_cleaned_email_addresses_in_df_manual.append(df_manual_cleaned_email_address) # Append the cleaned email address to the list_of_all_cleaned_email_addresses_in_df_manual
        list_of_all_mobile_numbers_in_df_manual.append(df_manual_mobile_number) # Append the mobile numbers to the list_of_all_mobile_numbers_in_df_manual

# df_website        
df_website['email'] = df_website['email'].str.lower() # All characters are in lowercase.
list_of_all_cleaned_email_addresses_in_df_website = [] # Create a new list entitled list_of_all_cleaned_email_addresses_in_df_website
list_of_all_mobile_numbers_in_df_website = [] # Create a new list entitled list_of_all_mobile_numbers_in_df_website

for index_number_df_website, each_email_in_df_website in enumerate(df_website['email']): # Use enumerate to get the index numbers of each_email_in_df_website
    if ' / ' not in df_website['email'][index_number_df_website]: # If the cellphone number was not provided with the email address...
        df_website_cleaned_email_address = df_website['email'][index_number_df_website] # The email address will remain as is
        list_of_all_cleaned_email_addresses_in_df_website.append(df_website_cleaned_email_address) # Append the email address to the list_of_all_cleaned_email_addresses_in_df_website
    elif ' / ' in df_website['email'][index_number_df_website]: # If the delimiter (' / ') is present in the email address...
        df_website_cleaned_email_address = re.split(r' / ', df_website['email'][index_number_df_website])[0] # Get the email string with an index of 0
        df_website_mobile_number = re.split(r' / ', df_website['email'][index_number_df_website])[1] # Get the phone number with an index of 1
        list_of_all_cleaned_email_addresses_in_df_website.append(df_website_cleaned_email_address) # Append the cleaned email address to the list_of_all_cleaned_email_addresses_in_df_website
        list_of_all_mobile_numbers_in_df_website.append(df_website_mobile_number) # Append the mobile numbers to the list_of_all_mobile_numbers_in_df_website

# 2. Mobile numbers must be formatted as +63XXXXXXXXXX (e.g., +639174005892).



# Reference 1: https://www.geeksforgeeks.org/apply-uppercase-to-a-column-in-pandas-dataframe/
# Reference 2: https://www.programiz.com/python-programming/examples/index-for-loop

# %%
list_of_all_cleaned_email_addresses_in_df_manual = []
list_of_fixed_mobile_numbers_in_df_manual = []

for index_number_df_manual_mobile_number, each_mobile_number_in_df_manual in enumerate(df_manual['mobile']): # Use enumerate to get the index numbers of each_mobile_number_in_df_manual
    for index_number_df_manual_email_address, each_email_address_in_df_manual in enumerate(df_manual['email']): # Use enumerate to get the index numbers of each_email_address_in_df_manual
        if ' / ' not in df_manual['email'][index_number_df_manual_email_address]: # If the cellphone number was not provided with the email address...
            df_manual_cleaned_email_address = df_manual['email'][index_number_df_manual_email_address] # The email address will remain as is
            list_of_all_cleaned_email_addresses_in_df_manual.append(df_manual_cleaned_email_address) # Append df_manual_cleaned_email_address to the list_of_all_cleaned_email_addresses_in_df_manual
        elif ' / ' in df_manual['email'][index_number_df_manual_email_address]: # If the delimiter (' / ') is present in the email address...
            df_manual_cleaned_email_address = re.split(r' / ', df_manual['email'][index_number_df_manual_email_address])[0] # Get the email string with an index of 0
            list_of_all_cleaned_email_addresses_in_df_manual.append(df_manual_cleaned_email_address) # append df_manual_cleaned_email_address to list_of_all_cleaned_email_addresses_in_df_manual
            df_manual_mobile_number = re.split(r' / ', df_manual['email'][index_number_df_manual_email_address])[1] # Get the mobile number with an index of 1
            # Transfer df_manual_mobile_number to the appropriate column.
            
            
            
#SAVE THIS            
#             if df_manual['mobile'][index_number_df_manual_mobile_number][0:2] == '09': # If the mobile number contains a '09' at the beginning
#                 df_manual_fixed_mobile_number_possibility_1_sub_2 = re.sub(r'(09[0-9][0-9])', r'+63\1', re.sub(r'\+630', r'+63', re.sub(r'(09[0-9][0-9])', r'+63\1', re.sub(r' ', r'', df_manual['mobile'][index_number_df_manual_mobile_number])))) # add a '+63' to the left of '09', delete the '0' before the '9', omit spaces in between
#                 list_of_fixed_mobile_numbers_in_df_manual.append(df_manual_fixed_mobile_number_possibility_1_sub_2) # append df_manual_fixed_mobile_number_possibility_1 to list_of_fixed_mobile_numbers_in_df_manual
#             elif df_manual['mobile'][index_number_df_manual_mobile_number][0:2] == '63': # If the mobile number contains a '63' (without the plus) at the beginning
#                 df_manual_fixed_mobile_number_possibility_2_sub_2 = re.sub(r'(63)', r'+\1', df_manual['mobile'][index_number_df_manual_mobile_number]) # add a plus sign before the '63'
#                 list_of_fixed_mobile_numbers_in_df_manual.append(df_manual_fixed_mobile_number_possibility_2_sub_2) # append df_manual_fixed_mobile_number_possibility_2 to list_of_fixed_mobile_numbers_in_df_manual

#OMIT
#             # Consider the case when there is no entry on df_manual['mobile']
#             else: # If the mobile number does not contain a '09' not '63' at the beginning
#                 if df_manual_mobile_number[0:2] == '09': # If the mobile number contains a '09' at the beginning
#                     df_manual_fixed_mobile_number_possibility_1_sub_1 = re.sub(r'(09[0-9][0-9])', r'+63\1', re.sub(r'\+630', r'+63', re.sub(r'(09[0-9][0-9])', r'+63\1', re.sub(r' ', r'', df_manual_mobile_number)))) # add a '+63' to the left of '09', delete the '0' before the '9', omit spaces in between
#                     list_of_fixed_mobile_numbers_in_df_manual.append(df_manual_fixed_mobile_number_possibility_1_sub_1) # append df_manual_fixed_mobile_number_possibility_1 to list_of_fixed_mobile_numbers_in_df_manual
#                 elif df_manual_mobile_number[0:2] == '63': # If the mobile number contains a '63' (without the plus) at the beginning
#                     df_manual_fixed_mobile_number_possibility_2_sub_1 = re.sub(r'(63)', r'+\1', df_manual_mobile_number) # add a plus sign before the '63'
#                     list_of_fixed_mobile_numbers_in_df_manual.append(df_manual_fixed_mobile_number_possibility_2_sub_1) # append df_manual_fixed_mobile_number_possibility_2 to list_of_fixed_mobile_numbers_in_df_manual

            
            
list_of_all_cleaned_email_addresses_in_df_manual
# Out:
# ['171dd05276fa26_f3e358791f84@hotmail.com',
#  'a66c0d16b47e186f081f16bb@protonmail.com',
#  'bc1fb61ff943.b3f0@hotmail.com',
#  'c3aba6f323c194ad8bc327f3.4503215d66e609db277f53@protonmail.com',
#  '81e5dc5216dc9881762a7b@hotmail.com',
#  '31b8ee563c63dfe2eed228dab2cfa59b@yahoo.com',
#  'a9cd54f1f9fade4cf3cf45ab.239a@hotmail.com',
#  '53fc53ad7af002a5625d9239@hotmail.com',
#  '0b1a4a8ba3b55dac739d.0e84e7@gmail.com',
#  'caa22054238b.711a4289@yahoo.com',
#  '7154f3459d16c517_c4bba17ae7a229c30b@yahoo.com',
#  'b3b2810ef05837_74a3a981637fe2@protonmail.com',
#  '3f470e9fe474bb15bb60.c80fa6696ad701c1991c103d6bd2@yahoo.com',
#  '641f0fbf1a86.66c4f0@gmail.com',
#  '4ba27209812ef4_f34dd6dcb3736f@hotmail.com',
#  '2ce16e5dcbea6eb487797a7b5b9b868c945d@hotmail.com',
#  '95e71f84739fee4b8ac8b70f_5f30aa4552c6@protonmail.com',
#  'f3cda4da6c6157fbec08659fb7f84d8a@yahoo.com',
#  '5009c65b25a27a_03dd7014@yahoo.com',
#  '1996d63c43.858f0f7c1cec@hotmail.com',
#  'a03b653d578e_4600a1abbcae@gmail.com',
#  'a0d8fa2c_1d43d6942f19c2277b2f@gmail.com',
#  'a2f79b310492a4328e7342fb819adba2@protonmail.com',
#  'c83190408f55a3e36f52.62138f2761f164@hotmail.com',
#  '9963af89b847adcee66c.021dd0ef@hotmail.com',
#  '1ccf85a5d7a3_c10c35905985b12e1fad0276b8@protonmail.com',
#  '844fa506a707f525_4e8215a93628a0697e@gmail.com',
#  '3fc79ab1e80c_1239a9@yahoo.com',
#  '0aa3f751_095d2ba4a3d35fc6a3d01b@gmail.com',
#  '38d62e20f64a723358ad.af7fd8dc9c51ab9907cb@gmail.com',
#  'bdde110fc7_7f8e22@protonmail.com',
#  '42239fa8eb32ef_0f7119@gmail.com',
#  'd68ca55aec.d064afc7cd672bcf86a468@hotmail.com',
#  'c86cb60ab61b58d0f338_66dd44256cb1@hotmail.com',
#  'fd3d16a8014a52@yahoo.com',
#  '6389dd_e52f81fba7fa2fcbb77f@gmail.com',
#  '1659c537bee53ef3df_796a1f46a020a31f6f@yahoo.com',
#  'a8ab48b931a039e04cb3edb09c574d@protonmail.com',
#  '8abc96a3517e_3e648ebf66de2a8ff7b40048a81c@hotmail.com',
#  '9d828c_18f6e1e6@gmail.com',
#  'a1a5706b71be633b4ffe.4a3a@gmail.com',
#  'b39284d34ac2913d924cba33.417cb6fea2260b519e@yahoo.com',
#  'baa53141db534c2ea57c5b.7c0038daebc8e5@protonmail.com',
#  '7f6cde4bc9a731a54b3c.c792c26fb9c47e4ab651c3fb4b@gmail.com',
#  '497fe3_9f4c328074190b93@gmail.com',
#  '5e33baf812ad8a573441db80_409621e3527d3a5c9582a7ebbc@yahoo.com',
#  'c3e1aa.d7fadd4b8c1e0272@gmail.com',
#  '34e53b16033c4ca11d.3ac28304@yahoo.com',
#  'aec2ca0bb0bc1ff902_324f@hotmail.com',
#  'cb676b5dc5daa3141dc1f7e7d0586e@yahoo.com',
#  'ae6a2c18a3_58b01382d87e39824c2d6323cb@yahoo.com',
#  '2536d063ec7abf92e6b1.bb521d7f940625@hotmail.com',
#  'd12ce8d6f7fb77db8e.4603bdad83@hotmail.com',
#  'bc02dfd369b621a6.0f6cb9531cdfa7@hotmail.com',
#  '321e1e28dacab93cbeb244b145994b2c@hotmail.com',
#  '376f6dcbfd35dbdf0ff07f5609c55acf56b5cf2ff6@gmail.com',
#  '8cd65a856a12.eb70719a76335aa6391c@hotmail.com',
#  '2c91d3806b1f0fb8cd954892f21e78aa18ee75e046f8@hotmail.com',
#  '0e85a865858a_955e58c22d46@hotmail.com',
#  '85dd7821f12f65a5b13f_a3c9b308a5a093a2c401@protonmail.com',
#  'a89430eefb91_ae8dbdb0a1b8759527d78eff1d@yahoo.com',
#  'f759037d824e86188e681956f3@hotmail.com',
#  '7aa0c2e6bbdcdc8e2d2cb6be0d6ead532c1a26@hotmail.com',
#  '40c5c6c091d0fbdc3e401ea246fb880816f0f3e46b8a@protonmail.com',
#  '196c247618.ce3b@protonmail.com',
#  'd70bbda065086cc2b6eeb91db436e827@gmail.com',
#  '21bb44688d_e46edfff3b@yahoo.com',
#  'def4898778_11f0443ac077df5c84c2c5e8@protonmail.com',
#  '77b5bbf73e93ab1e7d3f.2b6d10dc7343@protonmail.com',
#  '36aa5ee6f3fa1f0ae9319e_b61594c6fb90ec@yahoo.com',
#  '222df317e66a335527.ba78b16ee174a20b4cfa@yahoo.com',
#  'c6cf41fbdbe8b901cce146_0185@protonmail.com',
#  'cf1237f42444c70b_ebe3c347d240da2f32@hotmail.com',
#  '39a85729c9d963a143af3d1d_4aadc53976a0ba6bd65ed0fc914e@protonmail.com',
#  'dfb977c184b7e3.938002ef4558@yahoo.com',
#  '17609ebbec.1e31e78e4ae250bc@hotmail.com',
#  '1998c4c17c6082847de739c49508aa@yahoo.com',
#  '6eb317d66eeb35476d_33345931901063e8e5d10bfb7e@protonmail.com',
#  '127d91be3dfa0aef4bb8069c.b1dfad1d5586903497@protonmail.com',
#  '6e768fccdc3b4ea7459f91df71435b907be5728c@gmail.com',
#  '047b0c3e99a1ca46e7a2992f2021495e313070087924@yahoo.com',
#  'a3245f1b15e5c43645_a4f499@yahoo.com',
#  '645b74994d47843a99b916059a748f65b513ed2818355eeadb1f@protonmail.com',
#  'a1ed1c.cee66fb5@protonmail.com',
#  'c1e2a97bc9a08f17111f7821c8d4ece880@protonmail.com',
#  'a2981745_42fd13c44c@protonmail.com',
#  'a1cd3fd0d419e33ca706c09442b958@yahoo.com',
#  '71578c639ecf3e102f6ab6eb2979bfc3d8ac2a@yahoo.com',
#  'e5f094d3.526ad9d937791bdc@protonmail.com',
#  '176147.2509497c@hotmail.com',
#  'bf7f00f9257d21ee6cde@yahoo.com',
#  '702ea7ac36e7d83355e517f7@hotmail.com',
#  'fde8794c7931.dfbd4ceda87924721a0b751ab5e4@yahoo.com',
#  'f0b06a090a93b1280196ed_bba989eb96949db7445456d826@hotmail.com',
#  '43a9e2be4016_ab059054098e66f8cb@protonmail.com',
#  '017ca04fa021a58f7006b1d9_3967ab4632f312d59f@protonmail.com',
#  'e9ce71_c1d4f0dcabf922@hotmail.com',
#  '134d05d87f964602db8ee712.1aab2ebe5d5d8dddd4ebb6@protonmail.com',
#  '428a874332509dfc4b4591.61ed28048e7970c313e8f9e192@gmail.com',
#  'e24086ef215adf_ab99c640bd30ed@gmail.com',
#  'ea60d5fa09eac06521ad0c983d583201e4f80db8@hotmail.com',
#  '70529a90.80e9c06d98e1b0726b@protonmail.com',
#  '7c8ccce50da8a41e7e9f_9effeecc9f43@hotmail.com',
#  'fb70ce5e2c02f186a397c0_93257b89781e0e304ef41e2c05df@protonmail.com',
#  '9ceb69025590f3d3c5618a74@yahoo.com',
#  'e4d047279ac60d40de43165c5f0bce7fda6b2c@yahoo.com',
#  'e3567721f3d1512a7d94036ddb@protonmail.com',
#  '1d710b10143b_226ed077b996e750c9d9a08dcd03@hotmail.com',
#  'd41e562f46d3.946d01@protonmail.com',
#  'd057b60c1b8ad70cc61c3f993100@hotmail.com',
#  '9d64c0a55587391bb562ad9a9312@yahoo.com',
#  '84520b0572ed754fa8.cb2729dc01f3@protonmail.com',
#  '0730d49803cb1637da61fd.99a73c43f4@gmail.com',
#  'ab417b1dac33.5fce@gmail.com',
#  'd673bfd921eea937434b32236a9521@protonmail.com',
#  'a6e2ba_1c3c87f79d5e252d6bdc@protonmail.com',
#  '13ad1b3ef0c3e411cbb2.320916559fc80f3403@gmail.com',
#  '3c180c298404d2e212f00ee9_1a9f22@yahoo.com',
#  'adf2239f8a6f5d_0fec3d@yahoo.com',
#  'fe387d39005a3cf49e438a709eff6cd45d5a3c@protonmail.com',
#  'a47116060c40a52995de4f3f0b99fba0b1b42c70c99b@protonmail.com',
#  '2d3d7a12d4.22de51d613c02b20105fd9@hotmail.com',
#  'e2bfe007329161b3.c84931530c6107@protonmail.com',
#  '6d4fd5b46abfe502e647_1939bb27@gmail.com',
#  '35fd9d40159c6979c9_7136@hotmail.com',
#  '30e801e20b07433449607652ddbe1b3f55b48e@gmail.com',
#  'fee189e56e88548a3646.5f473f@hotmail.com',
#  '58989071433c3478aa747d.876f28c924d8032751b33f45@hotmail.com',
#  '511bc7512abedc20_21fe9d5b0e@protonmail.com',
#  'e320bc3eebed5c4623c8.02e022@hotmail.com',
#  '4aaa80459613.d46b194f0cdb1a@hotmail.com',
#  '05d4625c05bb22a0.f36ad0b829608036@yahoo.com',
#  'f1e9a7.87f9741b9e13cf6d6f@protonmail.com',
#  '58250bd357b0623a3f.5285c662e33bcf7c@protonmail.com',
#  'fa3613701d3237e1d8717bd04cfb@hotmail.com',
#  '635fc4fa67653f1cd326b7280a8e80dd@hotmail.com',
#  'afb6b2916c1bf9cf2dd26562aea4fe@gmail.com',
#  'd14bad666884_560a46373dc1@yahoo.com',
#  'fe5e24ee6683cd26ab83135f31af29031f@protonmail.com',
#  '13e9fd17922828.a843bf@protonmail.com',
#  'a2f10c446722b196b38573ccedb52eddc9ea8f3da8@gmail.com',
#  'eb76c47eac00a6.a5c4dd990c9b3e6fa031cf72@protonmail.com',
#  '7fb57947d5ed6189f98850e1018206@gmail.com',
#  '4ce3503976cb2bf1320e.2abcf5@protonmail.com',
#  '363c96_f5ee36@gmail.com',
#  '3c7145d5a0af5626a6f9ca_14f831672590@gmail.com',
#  '3234b6cf97927c672a.d6fbcf2d72041426dd2c@yahoo.com',
#  '8f68b7b8566be4fb04340da85fb96e64@hotmail.com',
#  'd03ae1ecdc.5652f5633c4a3203ec98ba3d63@protonmail.com',
#  'df245b64728d600a.d332ca07814bb969370d4e2176@gmail.com',
#  '9c65367f42c9f13b.ad156ec4374763cb56b2f79071@gmail.com',
#  '10f2cda34c8c1121212506@hotmail.com',
#  '72bc685b.17476b58582f2087cda380eb5391@hotmail.com',
#  'bc5d2264ae2b187f_77af4b2f6e1fbc3ea4d78f7e31da@yahoo.com',
#  '4ec0da6c74da_f655562c08287cc279@protonmail.com',
#  '07c32f9943b543b2dba88af3@hotmail.com',
#  '5f0eeee8.08fe7d939fbaae6fbfdc@protonmail.com',
#  '161c2429a58f13fb745de3_db60d5e0769492@yahoo.com',
#  '7030798adf9a22805aef05.8c70589085b47dfa0cec151997d6@protonmail.com',
#  '3387c4.f47984de981e7198a3@hotmail.com',
#  '5fd6b7052c9671d3ec6eff619ba59c6af3@gmail.com',
#  '4942522d966cd89502612e4e92ac46e0c014ab62@protonmail.com',
#  'ab35f45e1f484e10c25c.8b917e9edebb01725e552f@protonmail.com',
#  'fd1bc17411fd485a.ae8c@gmail.com',
#  '9c96a0df_9119f3@protonmail.com',
#  '8a349a5c73766264.0337e016a497defc5f@gmail.com',
#  'b6c6976435_d3e59339785e23c1f17b2c6e@yahoo.com',
#  '85abc3fc7193bd0f012d@gmail.com',
#  'f6c923.8a6a89@protonmail.com',
#  '446827170ef836ccb50651_de63@hotmail.com',
#  'ecadd97c4e22775b7e5da48c1c7d5d@gmail.com',
#  '87b1c7b46adf7674696f45001c71cdca96a29d@protonmail.com',
#  '0c12ef9d15451a8213ab50dbf1@protonmail.com',
#  'c4b4393e47616b41d8_48f0636bef23f6b90045e0a6eb@protonmail.com',
#  '8e1a970dd88c036ff881a4ce4a1c@hotmail.com',
#  'caf2ec9c48b0_19ad532aa36a20@hotmail.com',
#  '9f887fffd5b9265b3b69907ba0de717295810260@gmail.com',
#  'f5698725a3761bd61b256ee0_d1b874256ffc934c@hotmail.com',
#  '6c5f487f71986764921cbfdc53@yahoo.com',
#  '146be8d9d4363f91_3f4bc73974a203e0@protonmail.com',
#  '1e331172f5e544be65_82ebccbb435441@yahoo.com',
#  '9697a5c4_399ca03e47ddf12dd163f270b4@yahoo.com',
#  'cc23d6.534292699e206566f7f1c938@gmail.com',
#  '52d23e4d89b102_a8782779a5@protonmail.com',
#  'f24e623bec6c0ac2fcdbc0e4.5eeef3ac1e@protonmail.com',
#  '80969be029a96448e58d2b4a.66e41c782d2c81@gmail.com',
#  '921616cd27_6f5bb0@yahoo.com',
#  'bd0f3731cf954bb12b.b5794ad9608c607f@protonmail.com',
#  'f6150475562aa7dd24b1da@hotmail.com',
#  '5d00715ab69f0fbbf4.67e841@hotmail.com',
#  '7d6188.7d93@yahoo.com',
#  '6811a485c8_019951a6d516c4ed88687b59@yahoo.com',
#  '1bc7e12d9176_455770a6@gmail.com',
#  'e0114ead71_97eefa50@gmail.com',
#  'c75a92e6c918bbc0a3_28e23e81d63989@gmail.com',
#  '35fc8d71065bbe_2b30@hotmail.com',
#  '9fcc7a961241c85886c9.2e6b8d1c44127c0c09@gmail.com',
#  'd76a7c5dfa423699931e8fb7847500c074f903aa@yahoo.com',
#  '16ff45f96551d50ace@gmail.com',
#  'fa9431b3_90cd2f4ac76c395e891db10bcd@gmail.com',
#  '04656f1f8ad3.76223cd4bc20ff4f43eec694@gmail.com',
#  '522215dfa4520eacb87f78@gmail.com',
#  'ebefcb72bc6269.4645bb992a@protonmail.com',
#  'f6430a223a80cd5e_b6bd9b10aa1fdd3ef83a67@hotmail.com',
#  'c36e7daa76efb139bb@hotmail.com',
#  'a402f9ccbd_cf83152a830f01ae9de8@gmail.com',
#  'fa1168bb6f2d9a034168d0ea48c1cf@gmail.com',
#  '674423dea9.358f4fc3@protonmail.com',
#  '839905cc012c7abbfe9862a1.0c7b3094@hotmail.com',
#  '3ba5136c03b079.638ff7a152223dd3cf36bbcd27@protonmail.com',
#  '3b4c3bee16cb0248693c9b98055760ff9eb33705@protonmail.com',
#  '208abf257eea0485f66e22480c267fc9237690c1ad@yahoo.com',
#  '8d89bf00697a7bcc700cba11_7caa4a23aaa34886@yahoo.com',
#  'd4ac2495_3e32bb0647b2bf98ef3d96@gmail.com',
#  'dd0a1707.73d0d74a0e3c@protonmail.com',
#  '11d5170d979d7acc.3f1914f036f614d4@yahoo.com',
#  'f75b3c02b828ffeaaf.b4f2e0e5c77a97cf@protonmail.com',
#  '9c99f0d1478126_d0f4a300@gmail.com',
#  '096706d1cbdd3f0233bf97391814@protonmail.com',
#  '9a5649183e16.101b45c83c@yahoo.com',
#  '84d4aa13d52401dcd2dcaed7f78f9371240c0237@gmail.com',
#  '01bb71ebc70823_918646b8d1db93d3d0139b@protonmail.com',
#  '898a6ab17435db90_864382d460@protonmail.com',
#  'cf3cb632f8_6f243423b8@yahoo.com',
#  '83c21df9f87751e76f81.36b04cc013f08db0421b@gmail.com',
#  '804cd882175e7dbd_5a2f@protonmail.com',
#  'fb311caabf73c82cdfdf5d_daf610@hotmail.com',
#  'e74e6300b93d5f20d091f724c768@yahoo.com',
#  'e68bbdc9cb4f7237.fa55fde08bf7@yahoo.com',
#  'e5b1f3f52ae95879471b_35387523593f49d87d@protonmail.com',
#  'ee09163d38a037a74d88db.09661ece3cfa@hotmail.com',
#  '68d7a63a17183eed_f20c3f7794a22f9fddd13af5@hotmail.com',
#  '294609de4d9c80214501164f_e5f8946fce08e25a53cb@protonmail.com',
#  '6b8d2e3a8e173c1ff226509831f66f0f2ae12f5b0c@hotmail.com',
#  'c009109a8441d418.e1644fc162b4@hotmail.com',
#  '79cff3e6ee4f85.d3f8f54e1140797ef5248d@yahoo.com',
#  'b48813a6fe99af89f351_674acc5813577a@gmail.com',
#  '456842d85199cafee9cd92ed_d46222165aef493300c10e24e1@protonmail.com',
#  '20e22a9726238e79599c.a4c91ed2ef1cff44afec@protonmail.com',
#  '009746e340b161_d3af03bb553480c64052@protonmail.com',
#  '628b4b731a395c57.179da611635297a1@hotmail.com',
#  '289b5c_3e1fcece4bdae7@yahoo.com',
#  '0b01ec709f768e6041589494965e6a50@yahoo.com',
#  '606ee39d4ad79ddc_de2a1572@protonmail.com',
#  'cbd7570d8b.a90797@yahoo.com',
#  'dedce369.ebf2b2acd99d1d877e2d6845aa43@protonmail.com',
#  'c6f43f1fe4a1ff623caf@protonmail.com',
#  '9cb70600050172f512f3aa.ecf4@hotmail.com',
#  'c3e4ec3531a16a7cd6556919ae96b57a1c96@hotmail.com',
#  '1d4a925a.457087a2@protonmail.com',
#  '33ab48cdd040c1.ddd8a362808434837724ca@hotmail.com',
#  'bd19cf68b7_e51209e8ad457c7b4bde596573@gmail.com',
#  '9fea69123907d210.2cdf91470aa3fb9ae1@gmail.com',
#  '6ced47e90c86eb1de270df02c3@hotmail.com',
#  '5b78d8e7e4_6f3befe23b80@yahoo.com',
#  '4d2ae73094a627bc3beb8919e4ba@yahoo.com',
#  'c5628d.1a25212910b04efc3b@protonmail.com',
#  '73275ae613b483_bc73@hotmail.com',
#  '4684ad3dc3a29592fc6e256e226f706dd0389cb51607@yahoo.com',
#  'd398da1d700ee7d928_f2e1550bd30a@yahoo.com',
#  '550c6a594f1d9779.357a7a71a72b0dff@protonmail.com',
#  '2a6cf3f5993be9453eb31000f4e615e297ff9beb@protonmail.com',
#  '18668e1b0903b0ce6fa9_41aea6589c2913ee7040f6c0c7@yahoo.com',
#  '0fad86_f1ba9397581c40b682@protonmail.com',
#  '0408cc08049ccea02949.7cc3179a792b@hotmail.com',
#  'c759e10b68a9d2ac9e83e2e6@protonmail.com',
#  '353b8fff.5558edeb84dba4@protonmail.com',
#  '0b5733d7460c3df9_f101975454d58ee8@protonmail.com',
#  '59f21b361081d34b3bee5fa663f9a0@yahoo.com',
#  '57888ebf6b12b0.adde@yahoo.com',
#  '7606ea3c0cc938dba472@protonmail.com',
#  '66ea0609844cab0d621183.ed969a038ed299320c@gmail.com',
#  'c7817d7a68912186b4dcf3a3414b82b6099a2ecf998ec3c692@gmail.com',
#  '00702756b22cdae1_cc743021bc0e2c7a41@gmail.com',
#  'c0277e4165cbe3da2276_70ea859bb40fdbf9@yahoo.com',
#  '3d108d57.40814ace6feb55529359201e1a24@yahoo.com',
#  '7a322044020db0710da9.2256d8e6c5d6@yahoo.com',
#  '95f86fcdddf426_bf0c33da929c@protonmail.com',
#  'e0fb91295f62b9_1d1e99fb3a466bd3d4444d0645@hotmail.com',
#  'e7fad7a4c79cb620bf4b60ef_4fd7396bf858@protonmail.com',
#  'afce1a1dd9.3b6e59d655b70f@protonmail.com',
#  '34f0bbba6945b9795e_4e2115528a@yahoo.com',
#  '8065135f80850e3886417e2c45d0f62abf@protonmail.com',
#  '82db4ca1411dd152079738e579721c16301bf0ba60@protonmail.com',
#  '2e8f39656cf858fd_e297f3e56b346aca45769a@protonmail.com',
#  'b6675c_3466e55c4b9695204de43e89e2@hotmail.com',
#  '3c0c1b500ef461638e6e216ad303f1ae7322@protonmail.com',
#  '53abacc42c833b3ceafda9506f5f52ba999f739b@protonmail.com',
#  '81521051e3edeb14507f0a19_27eff62a37@hotmail.com',
#  '2c733d5feb689adc.45c4fd72@yahoo.com',
#  '2662e924ae4d5422ab53bf113184c01b@protonmail.com',
#  '12ded67bd5e23730c9f6c9_d453b3@protonmail.com',
#  '54b3a1d7_26b9257035558be2cabb8442@yahoo.com',
#  'beecb9c21befb92d56262800d0eba109@yahoo.com',
#  '3fa10cc1d66a57.594258@yahoo.com',
#  'fa7ee8f65047e7af_db25e936539868273a@gmail.com',
#  'fa3e780dd568abb5575b53.2687c6c6ce93@gmail.com',
#  '90974c04cb0b800736ad18d9b5a57bac@protonmail.com',
#  '6b4f670a_a93b5f754f2b61fa@hotmail.com',
#  'aed1e5bcce024c6c021230.f31f104111@hotmail.com',
#  'b8b6aa546f317fcdac3ff4b1d0d28f284c33b88a@hotmail.com',
#  '3b094c97f1b1f1ff3b412544a050f3b976b42f@hotmail.com',
#  '2c6ec45bcb7f0bb5eff3d9.269b2f55009744d75f172c@yahoo.com',
#  'f2917acae1f6df53269af8@gmail.com',
#  '2b316b823ac0d42afcca19.805bf60972fc3a7cd970b0ed@gmail.com',
#  'a69a43eb.cc2b2308d8ede7d5062f@hotmail.com',
#  '99ea268575988b40@hotmail.com',
#  '0eba837197c89661d83766d1729d66@yahoo.com',
#  '361b7f860b4040ce29a69a@protonmail.com',
#  '17c0d8b6_de1ead5fd840@yahoo.com',
#  '1539f9ad43bdc6cace50_80a1bacd692cb125787b64c7d976@gmail.com',
#  '1a62ea55a2678e_1eddb328@protonmail.com',
#  'a26c3351325c_c4a7ab7b3b540f6b@hotmail.com',
#  'fd2841.01426cc269c99a8abe1a@hotmail.com',
#  '6e0ef1ac3d765c94b387684a_1e53d818e634@yahoo.com',
#  '2de1858bb20c418b9fad37505e6c05ea@protonmail.com',
#  'c514523bfe63d0015937edba9998014c3d@hotmail.com',
#  '85b4c09fa411_98bd9911927ce9c35f@gmail.com',
#  '55bfabfe8cc28781f1347201e9d0a0a20a92@yahoo.com',
#  '99017302bc319e_c0afd270fe9d627f6f@gmail.com',
#  'b30b5c5db92d.04a064ae7223@yahoo.com',
#  '7b20bb994213.ee878b3d1054@hotmail.com',
#  'dd51018008675df5c6@yahoo.com',
#  'fd30ddc318f1@protonmail.com',
#  'ab45522a2a81f100d502_1cb7@yahoo.com',
#  '22ab2b81146af321633e2d.83c80a881a854f455deb90@hotmail.com',
#  '83190cee5047dd0f_28873723afd8b2fa@hotmail.com',
#  '77c4906d7dce820f64@gmail.com',
#  'eef8bc0e87_7520e6bbe6913f94@yahoo.com',
#  '8d9f0156f6be450352057f13f27be9@hotmail.com',
#  '9c5e6492ebb9b70eb7b839.f1a60a158e920b@yahoo.com',
#  '690f2387b3_9aee8a0b4067e798ac@protonmail.com',
#  '7cd24afed98545d1077c0022.20fa97e5e62136b82c8c6c8799@hotmail.com',
#  '71abe2cbe9460497.7db5eb9597b2c862c61e6d@protonmail.com',
#  '6816da9efc7ab45125.b899de5ae713ddd4568104@gmail.com',
#  'e0078bd1894172b68ead_d9ad63afbf16522f9d1975f3@yahoo.com',
#  'a50ad28851b40c5137805cc38474c1@protonmail.com',
#  '37bfdeca.ccc354e481a587eb2ac5af@protonmail.com',
#  'd8eb0544.2cf2606d2f@yahoo.com',
#  'ebc4b237.68de39b31b4c28736346c4@yahoo.com',
#  '55716aa526896b59256cb451.b45daf171cf8350ff70443139d@gmail.com',
#  '065f2647b8a3b57f17ea81.b219d9c4fd4446c3a3fbabdba7@yahoo.com',
#  '6af48fccb3_640e@hotmail.com',
#  '266ce5ea13cc589f@protonmail.com',
#  '28545384f2286abc905c.e2fbc4@yahoo.com',
#  '5fc2b12578ba05_55addc1b03d1f2823d61c594d1a0@yahoo.com',
#  '1dc2415653a7f6ea9912315959cff465@gmail.com',
#  'cf990802f0690e90a7aa_c0ed22fa98365344@protonmail.com',
#  '9226f1da11.3d719162@hotmail.com',
#  'f9c6b1407381_7776c626db23@protonmail.com',
#  'aec4ef75dcf85c78_51dc5ae919a9783774@yahoo.com',
#  'b5bf7e8f1b_7819316f316a740029@protonmail.com',
#  '39801b969923_846c77f54a1948@protonmail.com',
#  'f49f809d2de5b7_0c5acc7a83176a923afe@hotmail.com',
#  '4658263f967de073325606254d0121cb22045b@yahoo.com',
#  '0f137d0373c01b95bd245597df@hotmail.com',
#  '821ef1eb3f3d48db47@yahoo.com',
#  '28aa1591.88c019b2c9f08e@gmail.com',
#  '9fb02626.2ad185@protonmail.com',
#  '771ccde54482217160a8.6743eca4836ae210a474@hotmail.com',
#  '046117e5d6dcd29cc28488fb0d18bd@protonmail.com',
#  'a826980e3a4304484e34.5986adf7b45f@protonmail.com',
#  'a082cbe512fc3fa2e264@gmail.com',
#  '14ac3f2d9781e1_1959f38a9e126d8bd4@protonmail.com',
#  '1b03c0a14341_f8637c725035fd6e0d7b@gmail.com',
#  '10336199.f48ef1da23b5130b@protonmail.com',
#  'de7d0502a73ff07d459d23a6.5ca836930b8147@hotmail.com',
#  '2002be_9935b3d3ce58d92696c530@yahoo.com',
#  '9ceb7b086527aa312a95e46e.296656@hotmail.com',
#  '8259f77e_56a8f17cc5ed6a2a@hotmail.com',
#  '82699b4d6c34104767.80ea960f79aeaef370b528c88776@hotmail.com',
#  '289ed26b19.069f2899e8e168@hotmail.com',
#  '675f82ba97768eb2.df16d60b80@gmail.com',
#  'bdc5bdd72dff83ec531c0eea_34179af302b5043b40d4@protonmail.com',
#  '296c34d6ac0810eef37b6b607e6888b1@gmail.com',
#  'a21ffdc69d615499_e5c4e08c1d4f3767@protonmail.com',
#  'a5aaa6e6_7dd81b@gmail.com',
#  '6c0ac5.b91429c64cb05c@gmail.com',
#  '9ea84690d7aa43e041dd.72a61f@yahoo.com',
#  '4138313759a0521ef2f728753117194e40319d10@hotmail.com',
#  'ad526b80.88f47b295f2f6244cf6c18@gmail.com',
#  'b87f962ffca939bba1_895a01914a1db2fc0d3b47@yahoo.com',
#  '88fb89_28bcec8c9b084f47dfbb35@yahoo.com',
#  'a72c13a53f447e60d9f18595.fc902a12@yahoo.com',
#  '04bd9e9c7322b7b0@yahoo.com',
#  'c30f996904354a6c3c42400307bc2be638@yahoo.com',
#  'b57c82ba936d13a01077b3ecd5044de959cabeaedc@yahoo.com',
#  '949ecc50b660c5_2d28@yahoo.com',
#  'ceaa91adfd08d29f5b8aa23d3fae9679b03c@protonmail.com',
#  'afa103ad5f9ee11d744e68d022b1e8ea534be04afcec@yahoo.com',
#  '90e931.035e@gmail.com',
#  '5c5d1d6b93bc28136c856b.0760b284d45568656aae5e0e1d24@yahoo.com',
#  '7aac328b1014ad@gmail.com',
#  '951673_4607@hotmail.com',
#  '3b0641b5f830074a9c_55948f3e2ecb@protonmail.com',
#  '7840f96bd68404_df4a1f65865322df98@gmail.com',
#  '0e9164a68d626359a49748.4385ed75c6d312f7@protonmail.com',
#  '863e6e4c4753_531e1c920856a87f1c5c85b43474@hotmail.com',
#  '6f65b2c909.2c6a45abaeedee41d4fd@gmail.com',
#  '16e04148d4d0f1e8d72d3622605425379da608cf51e2c2@hotmail.com',
#  '0e485fa54e5f3f_5e42747efc5ad2874a@hotmail.com',
#  '0716bfdf.d44d87fe@protonmail.com',
#  '01282f45_4410@protonmail.com',
#  'ce6205293f_30f1f31e80201272@hotmail.com',
#  '100c93a3f8_52034502bc@yahoo.com',
#  '2249a2b7ac900bab4758da78.d22ce941a7e95842f579bedc8c@gmail.com',
#  'eb475a3eaad4.d52820c7@hotmail.com',
#  '34d74455d61db750756ade82becd6fe28e29ed56@yahoo.com',
#  'cfb860687627978caea93c@yahoo.com',
#  '083a43d128_91250293a48c9a81ce394c9beadd@protonmail.com',
#  'd66c406b427d973f45fee3500384eeae496e@yahoo.com',
#  '3f9ad93def_307c2a50@yahoo.com',
#  'c8e61c8243bfc2686e835fd9_9b8f6dfdc9@gmail.com',
#  '30f8c3d1f7fc38e1c78bad23ec2648@gmail.com',
#  'd57d042726b1ad1632103d1b81@yahoo.com',
#  '04d77367c5c70eaf.884d74af6f1f@protonmail.com',
#  '99cbbf94279dc5ad_84333db7@gmail.com',
#  '4d2047f7d55ae7.011b11ce184535bd@yahoo.com',
#  '42f500fb9251ee.ce1272fc86@yahoo.com',
#  '2485b60e.258b29fe7fd1eecf@protonmail.com',
#  'ae4393d7ae1cf4dc59094b_4fbf@gmail.com',
#  '43450693bf5f3a3a7f_9c40690bd6ace57e992c0b@gmail.com',
#  '0b1d0479.5d5ff940674f5ad9@yahoo.com',
#  '144017.d0845c8a136c0806459fd764a704@gmail.com',
#  '96c9526aa608f6afa8881441@protonmail.com',
#  'acea2a90addbbe33@gmail.com',
#  'b21fb78a6bcb37ed7c3f76dcb8fef5@protonmail.com',
#  '1dd39d3b8c1379@protonmail.com',
#  'fc7e1b_07b3ece8905f7cc996aa@gmail.com',
#  'e1c146e2a1_399787b4@protonmail.com',
#  '74d172fa395322_5365c746ed506ee8a1a34a62dc@yahoo.com',
#  '32a715da14ed002f1777220f0cbb@protonmail.com',
#  'd97ce3.f272b07c003f@hotmail.com',
#  'f1f1af74_322cb061e88c3a@protonmail.com',
#  'c84701f1f12f0f9260@yahoo.com',
#  'f7b3f1a288b806c8c0.80514ecc2c792b@gmail.com',
#  '368770.cfc6614a@gmail.com',
#  '32133496f42251@protonmail.com',
#  'eefc4127ea.9086f4@protonmail.com',
#  '9ca7972fbb1edc_888d35912cb69e2f11a9c8c7@gmail.com',
#  'c5f5915929_73fa561e712a93697eea524dfe24@protonmail.com',
#  '0530cd5f1a3225ba6cda3d084dda@hotmail.com',
#  '652a0d867af689363ba7dbc01b@yahoo.com',
#  'e77106f2f48f6fbc.5f48c4a5c3f0f8bbc311@protonmail.com',
#  'a5f9984302.f218a162dc8185b2ae2e5ad146ab@gmail.com',
#  '7f2a095b5c4b4c_d8790a30a4e1df0c9ed15a@gmail.com',
#  '7a2ce744_a0b49e5b6db6@hotmail.com',
#  '9c6621a6.c90e50210d988b7a16@gmail.com',
#  'f32f904545e3e80c4beb4d.7448@hotmail.com',
#  'fc92ef4d872ba1d300be.9d5974908a9753b8d41e@protonmail.com',
#  '04f553392af52049f17f4016a9f60cc7@gmail.com',
#  '6a51756bf4c6fdfe2ce3605c76f164a5a415@protonmail.com',
#  '3edbc9fcae79d575@protonmail.com',
#  'ab5b6bc8524d7c7e9580a4853b5f57@yahoo.com',
#  '1f8553654264044d4c793c1139fc265970f0264f@hotmail.com',
#  '8b814395fdc8c3d0a3fca324f47845@hotmail.com',
#  '36f0b824de61_0680efbd9b34b51ccdce695bfbcd@protonmail.com',
#  '53f7f685.0e1baed17ad46495@gmail.com',
#  '322d30c70e41450b@gmail.com',
#  'f6386c712cb25200290c0c4a8d39579a@yahoo.com',
#  'b5feb67fb4572c2f048c735b.bbdb40c720@yahoo.com',
#  'a946e535596b.ee3bc8@yahoo.com',
#  '660b77e2b9a19f88815c1d5646c4498a46c873d739@gmail.com',
#  'b74cf579b7.91fa9572af87@protonmail.com',
#  '4e79663c42d514ed02f32d42@gmail.com',
#  'ab81b4c60096b33c8202f434a586d96817@yahoo.com',
#  '285a010276150a.a95890eecc4a7666d6a2@protonmail.com',
#  'ef0e3fac4dbe67_fdcf302b@hotmail.com',
#  '88b10cc645ea_2378a6@hotmail.com',
#  'edf33b810e46497f36d2e2@protonmail.com',
#  '5b2856c1e2ad13ff0275916d@yahoo.com',
#  '019c2d31044e356fc54c_1bed8f3b884cc5645f914738f448@hotmail.com',
#  '75e67910805b8b494bfa928c054fd9@protonmail.com',
#  'ada57e99e1db2e91392e5dc6c4e24d@gmail.com',
#  '58b7eaf1fef4ec6a.3c361b@yahoo.com',
#  'a50b9282_1eb6dc96c14d41be8f428219ab05@protonmail.com',
#  'a421fcc186af042087a8fd70e5f89675@protonmail.com',
#  '0c3e348b2413e8.8b8c7b981f@protonmail.com',
#  '876dc44a0d466976.3add7198ddcc5df477632b9f9c80@yahoo.com',
#  '82a3b1bb82a7.cf5f7d5da7f22e2609d91bd801ca@hotmail.com',
#  'e9599ceb00f8c54a@hotmail.com',
#  '4f693328362fc7b8167d6b7860fee169@yahoo.com',
#  '7d829752d71e2d.277fc6e7573c@hotmail.com',
#  'ae64b98d9c0f6173_64c2bdcd65ee@hotmail.com',
#  '8a0b3be54276cfb215bf0117.735f881376899f8223@hotmail.com',
#  'd5befd0850ff20ad639ef0bd96@protonmail.com',
#  'eb085d0f.b22c87312061ffd40c@protonmail.com',
#  '1a9149ac7a_6be0e828e78981f36a@yahoo.com',
#  '4c4c7d1ac5874e.49067fda@yahoo.com',
#  'e96f2dee8815227d1321c732.f0c095e5d52fa01a@yahoo.com',
#  '7cf3ee2f0ce0820d.76623328b14847@hotmail.com',
#  '7a230aca110f_11fa79fde805@gmail.com',
#  'c2eddb8f1e49319de0dc54bfd7e9367820b754f42f5f@hotmail.com',
#  'b93462d1c8b1b4.48c9784fadeb6d51@yahoo.com',
#  'd03f89d2ef583f111b@gmail.com',
#  'ca9a1591b86151_0b29c29ff5e379a5@gmail.com',
#  '0aa3c77c65f0b96631_3457484851@yahoo.com',
#  'f97ed2bd81293d_dc9fb3a0c7@protonmail.com',
#  '1072b8654564c8387d_3d50309ac5d2ed3f62491d@yahoo.com',
#  'a73d93401f_4ac9b00d6d3b3d1c80c6b958de2d@hotmail.com',
#  '87c25975e530f06197f0a4a0.1c439069a57e5c658967c8@protonmail.com',
#  '2f9b0cdd678f23bd03.db13@protonmail.com',
#  '13c1d0ce16.3ebd1698037f01@hotmail.com',
#  '3c69f30abc6ae0e1479d4b.2d44883979d5956e816f6b1855@protonmail.com',
#  '747cc1e5db8051.a25a81ebe4fb97350bd5526a58@gmail.com',
#  '7ffb3317205c4c6237ec4c8f7b@gmail.com',
#  'add08e8c52280d0e1e10b549_68752de6faeed59a7fabc6134703@yahoo.com',
#  '4b7202639e3f782a16e555a0.85a5d4e48665de7ed3ddd96c0493@yahoo.com',
#  'd1d2b6951de4d7e7@protonmail.com',
#  'b3415ab236bdbc875f3f90446ec00a4196cea52d@gmail.com',
#  '436c164dd8e241d49ff53129.791ef14a6243c4981349a02b@protonmail.com',
#  '5e705928e2e0a09e@hotmail.com',
#  'e556027ad6a352ca_1016ed6cfe5d59a007b94108@hotmail.com',
#  'abfcb554ceb1_cfad2a4f896696a2a2cea2d997@gmail.com',
#  '239eead5fa_b76f498340de@gmail.com',
#  '2aad638e.8d2db793a46055@protonmail.com',
#  '09e616.57beac6fd642f65f@gmail.com',
#  'ccab6d45a38cbee533_329d664a6291c99a32d7adbbbf@protonmail.com',
#  'adfe1d281e8a51d0c43d3ebdeb6b14@gmail.com',
#  'cde38f2916_d4e03de169aa8341195c0a@gmail.com',
#  '625b402d05f3109326c66e7bce50b73774427a0866033de9@gmail.com',
#  '573f359ff9_6625343536e2b40a2d7ef008@protonmail.com',
#  '9b6ab10b2e_96fe75433c871eec7cf2bd@yahoo.com',
#  'b9fa781b280b1020.234770cc9b269c966aea192f@hotmail.com',
#  '4ff38a96960bfeb4993f23.243a3c4219cbc1a5@hotmail.com',
#  '6dd1e0ebb2b4f0_7033c20a970999@protonmail.com',
#  '6b3a0111baaa_2e42a067@hotmail.com',
#  'a1a64f16de2bebb6a9.543ec1e6b62bfb@hotmail.com',
#  '8c32c35657@gmail.com',
#  '0972de7412e55f6bd54d73c2606d@protonmail.com',
#  '633f852c3b8e1118e4bb71749defbd2efd351558fa@gmail.com',
#  '23ec01e7e921d27889_0419b6e49287@hotmail.com',
#  'd43630909ff274.3ef231@protonmail.com',
#  'a556826af0d5bb8d_d478840e340146051d3e36ed@gmail.com',
#  '149f44bef38730284d280adf@protonmail.com',
#  'abec1e_38b365328a36744a799220c0@yahoo.com',
#  'e9b457_43bb105d3e4ab419fb1540@protonmail.com',
#  '43950ef3.cc4d836c4452673a@protonmail.com',
#  'e2891ad91bc2.c464cd8be3df62c4@protonmail.com',
#  '985bc49a8602bbbb9501baee_bd5d@gmail.com',
#  '90c6a10650_432c3a933af69723df@yahoo.com',
#  '03950c36.d610d04b0167d0d93160963c9452@hotmail.com',
#  'b8357d164173826d0903_9c4e6ef6@hotmail.com',
#  'ccd7c813c39a8805_61012dc63901@hotmail.com',
#  'f31dab62427d34.ca53fa1cbb96c3fcc0@hotmail.com',
#  'd3811ac6c12c49e336ff5a6c070983387a1d3978@yahoo.com',
#  '89230a7bd189c7e523219e10327e4827e03b49c8@yahoo.com',
#  '713491b37947ad29ebfb9c4c8a748a353712@protonmail.com',
#  '0b750a4f2c7378b7.28dbf852738251b47e7120@protonmail.com',
#  '227785bd5f4524614d59235bfb30@protonmail.com',
#  '8fde8501f0c440_8a705551097926a339aa@protonmail.com',
#  '389a920575.08f624800432e014ccd429efc2@protonmail.com',
#  '6187188956aa544a_6ee35f1b681fae816ff1@gmail.com',
#  '6c26a47801b9092150592cd780@yahoo.com',
#  'f37f7b_c60769@yahoo.com',
#  '6d4331d4ebca4ecdac11@hotmail.com',
#  'd8bd02e0f24c267620d6514220a26d2c5c78f3@hotmail.com',
#  '0ac990284c7f7850.af42@protonmail.com',
#  'b99dccc6af50832a8699.6c296829de@gmail.com',
#  '1822978796c20f3f4c5f5c33de19f2f50170b922ffd233@gmail.com',
#  '650a8d.ba88ee13112197@hotmail.com',
#  'e7978461c8e9a4a767af@gmail.com',
#  'e620377913693794c132b47b6b78de30f8@yahoo.com',
#  '1e13dc2717378e818c2ea73c547295@yahoo.com',
#  '1cb0e2cc978252_9ce6f022c1c520bfcad6e86e@yahoo.com',
#  '24aae25d.cea57097277457387f3bbe@gmail.com',
#  '50f1fd335cb041013fd2f723.c8b9102aece73d80776bf9@hotmail.com',
#  'a2f83570.43933c12046171c9d01c5e297358@yahoo.com',
#  '5524adfa09.065d45cc719d270f0b4c@hotmail.com',
#  '7f94498db2d70ef69bdfd8c71a68c47d6f96@hotmail.com',
#  '042b9fdef1.95c7aa5b@protonmail.com',
#  'b3bad4c1_dafe27276f8d0b40@yahoo.com',
#  '3efb423d4386@hotmail.com',
#  'cf00bc7c84f5de0b46a6@protonmail.com',
#  '0175363c9ccddd84bea3ff9ffabf1d6427@gmail.com',
#  '8fc998bb8563464c54ac72f582d1153b950a41@hotmail.com',
#  '64c09663e3@gmail.com',
#  'ec29ac325b.e3e7@protonmail.com',
#  '82e33411347efbe1_f25d0e@hotmail.com',
#  'bbf6458cf7ee767adffbea87d6f7e1@yahoo.com',
#  '48aa0504ddc853ac7295a5.2d877feab9939cb5153e0ca819@hotmail.com',
#  'd56db8a879589a8bed4e90_23e70aaa629fcef1cd@gmail.com',
#  '171dd05276fa26_f3e358791f84@hotmail.com',
#  'a66c0d16b47e186f081f16bb@protonmail.com',
#  'bc1fb61ff943.b3f0@hotmail.com',
#  'c3aba6f323c194ad8bc327f3.4503215d66e609db277f53@protonmail.com',
#  '81e5dc5216dc9881762a7b@hotmail.com',
#  '31b8ee563c63dfe2eed228dab2cfa59b@yahoo.com',
#  'a9cd54f1f9fade4cf3cf45ab.239a@hotmail.com',
#  '53fc53ad7af002a5625d9239@hotmail.com',
#  '0b1a4a8ba3b55dac739d.0e84e7@gmail.com',
#  'caa22054238b.711a4289@yahoo.com',
#  '7154f3459d16c517_c4bba17ae7a229c30b@yahoo.com',
#  'b3b2810ef05837_74a3a981637fe2@protonmail.com',
#  '3f470e9fe474bb15bb60.c80fa6696ad701c1991c103d6bd2@yahoo.com',
#  '641f0fbf1a86.66c4f0@gmail.com',
#  '4ba27209812ef4_f34dd6dcb3736f@hotmail.com',
#  '2ce16e5dcbea6eb487797a7b5b9b868c945d@hotmail.com',
#  '95e71f84739fee4b8ac8b70f_5f30aa4552c6@protonmail.com',
#  'f3cda4da6c6157fbec08659fb7f84d8a@yahoo.com',
#  '5009c65b25a27a_03dd7014@yahoo.com',
#  '1996d63c43.858f0f7c1cec@hotmail.com',
#  'a03b653d578e_4600a1abbcae@gmail.com',
#  'a0d8fa2c_1d43d6942f19c2277b2f@gmail.com',
#  'a2f79b310492a4328e7342fb819adba2@protonmail.com',
#  'c83190408f55a3e36f52.62138f2761f164@hotmail.com',
#  '9963af89b847adcee66c.021dd0ef@hotmail.com',
#  '1ccf85a5d7a3_c10c35905985b12e1fad0276b8@protonmail.com',
#  '844fa506a707f525_4e8215a93628a0697e@gmail.com',
#  '3fc79ab1e80c_1239a9@yahoo.com',
#  '0aa3f751_095d2ba4a3d35fc6a3d01b@gmail.com',
#  '38d62e20f64a723358ad.af7fd8dc9c51ab9907cb@gmail.com',
#  'bdde110fc7_7f8e22@protonmail.com',
#  '42239fa8eb32ef_0f7119@gmail.com',
#  'd68ca55aec.d064afc7cd672bcf86a468@hotmail.com',
#  'c86cb60ab61b58d0f338_66dd44256cb1@hotmail.com',
#  'fd3d16a8014a52@yahoo.com',
#  '6389dd_e52f81fba7fa2fcbb77f@gmail.com',
#  '1659c537bee53ef3df_796a1f46a020a31f6f@yahoo.com',
#  'a8ab48b931a039e04cb3edb09c574d@protonmail.com',
#  '8abc96a3517e_3e648ebf66de2a8ff7b40048a81c@hotmail.com',
#  '9d828c_18f6e1e6@gmail.com',
#  'a1a5706b71be633b4ffe.4a3a@gmail.com',
#  'b39284d34ac2913d924cba33.417cb6fea2260b519e@yahoo.com',
#  'baa53141db534c2ea57c5b.7c0038daebc8e5@protonmail.com',
#  '7f6cde4bc9a731a54b3c.c792c26fb9c47e4ab651c3fb4b@gmail.com',
#  '497fe3_9f4c328074190b93@gmail.com',
#  '5e33baf812ad8a573441db80_409621e3527d3a5c9582a7ebbc@yahoo.com',
#  'c3e1aa.d7fadd4b8c1e0272@gmail.com',
#  '34e53b16033c4ca11d.3ac28304@yahoo.com',
#  'aec2ca0bb0bc1ff902_324f@hotmail.com',
#  'cb676b5dc5daa3141dc1f7e7d0586e@yahoo.com',
#  'ae6a2c18a3_58b01382d87e39824c2d6323cb@yahoo.com',
#  '2536d063ec7abf92e6b1.bb521d7f940625@hotmail.com',
#  'd12ce8d6f7fb77db8e.4603bdad83@hotmail.com',
#  'bc02dfd369b621a6.0f6cb9531cdfa7@hotmail.com',
#  '321e1e28dacab93cbeb244b145994b2c@hotmail.com',
#  '376f6dcbfd35dbdf0ff07f5609c55acf56b5cf2ff6@gmail.com',
#  '8cd65a856a12.eb70719a76335aa6391c@hotmail.com',
#  '2c91d3806b1f0fb8cd954892f21e78aa18ee75e046f8@hotmail.com',
#  '0e85a865858a_955e58c22d46@hotmail.com',
#  '85dd7821f12f65a5b13f_a3c9b308a5a093a2c401@protonmail.com',
#  'a89430eefb91_ae8dbdb0a1b8759527d78eff1d@yahoo.com',
#  'f759037d824e86188e681956f3@hotmail.com',
#  '7aa0c2e6bbdcdc8e2d2cb6be0d6ead532c1a26@hotmail.com',
#  '40c5c6c091d0fbdc3e401ea246fb880816f0f3e46b8a@protonmail.com',
#  '196c247618.ce3b@protonmail.com',
#  'd70bbda065086cc2b6eeb91db436e827@gmail.com',
#  '21bb44688d_e46edfff3b@yahoo.com',
#  'def4898778_11f0443ac077df5c84c2c5e8@protonmail.com',
#  '77b5bbf73e93ab1e7d3f.2b6d10dc7343@protonmail.com',
#  '36aa5ee6f3fa1f0ae9319e_b61594c6fb90ec@yahoo.com',
#  '222df317e66a335527.ba78b16ee174a20b4cfa@yahoo.com',
#  'c6cf41fbdbe8b901cce146_0185@protonmail.com',
#  'cf1237f42444c70b_ebe3c347d240da2f32@hotmail.com',
#  '39a85729c9d963a143af3d1d_4aadc53976a0ba6bd65ed0fc914e@protonmail.com',
#  'dfb977c184b7e3.938002ef4558@yahoo.com',
#  '17609ebbec.1e31e78e4ae250bc@hotmail.com',
#  '1998c4c17c6082847de739c49508aa@yahoo.com',
#  '6eb317d66eeb35476d_33345931901063e8e5d10bfb7e@protonmail.com',
#  '127d91be3dfa0aef4bb8069c.b1dfad1d5586903497@protonmail.com',
#  '6e768fccdc3b4ea7459f91df71435b907be5728c@gmail.com',
#  '047b0c3e99a1ca46e7a2992f2021495e313070087924@yahoo.com',
#  'a3245f1b15e5c43645_a4f499@yahoo.com',
#  '645b74994d47843a99b916059a748f65b513ed2818355eeadb1f@protonmail.com',
#  'a1ed1c.cee66fb5@protonmail.com',
#  'c1e2a97bc9a08f17111f7821c8d4ece880@protonmail.com',
#  'a2981745_42fd13c44c@protonmail.com',
#  'a1cd3fd0d419e33ca706c09442b958@yahoo.com',
#  '71578c639ecf3e102f6ab6eb2979bfc3d8ac2a@yahoo.com',
#  'e5f094d3.526ad9d937791bdc@protonmail.com',
#  '176147.2509497c@hotmail.com',
#  'bf7f00f9257d21ee6cde@yahoo.com',
#  '702ea7ac36e7d83355e517f7@hotmail.com',
#  'fde8794c7931.dfbd4ceda87924721a0b751ab5e4@yahoo.com',
#  'f0b06a090a93b1280196ed_bba989eb96949db7445456d826@hotmail.com',
#  '43a9e2be4016_ab059054098e66f8cb@protonmail.com',
#  '017ca04fa021a58f7006b1d9_3967ab4632f312d59f@protonmail.com',
#  'e9ce71_c1d4f0dcabf922@hotmail.com',
#  '134d05d87f964602db8ee712.1aab2ebe5d5d8dddd4ebb6@protonmail.com',
#  '428a874332509dfc4b4591.61ed28048e7970c313e8f9e192@gmail.com',
#  'e24086ef215adf_ab99c640bd30ed@gmail.com',
#  'ea60d5fa09eac06521ad0c983d583201e4f80db8@hotmail.com',
#  '70529a90.80e9c06d98e1b0726b@protonmail.com',
#  '7c8ccce50da8a41e7e9f_9effeecc9f43@hotmail.com',
#  'fb70ce5e2c02f186a397c0_93257b89781e0e304ef41e2c05df@protonmail.com',
#  '9ceb69025590f3d3c5618a74@yahoo.com',
#  'e4d047279ac60d40de43165c5f0bce7fda6b2c@yahoo.com',
#  'e3567721f3d1512a7d94036ddb@protonmail.com',
#  '1d710b10143b_226ed077b996e750c9d9a08dcd03@hotmail.com',
#  'd41e562f46d3.946d01@protonmail.com',
#  'd057b60c1b8ad70cc61c3f993100@hotmail.com',
#  '9d64c0a55587391bb562ad9a9312@yahoo.com',
#  '84520b0572ed754fa8.cb2729dc01f3@protonmail.com',
#  '0730d49803cb1637da61fd.99a73c43f4@gmail.com',
#  'ab417b1dac33.5fce@gmail.com',
#  'd673bfd921eea937434b32236a9521@protonmail.com',
#  'a6e2ba_1c3c87f79d5e252d6bdc@protonmail.com',
#  '13ad1b3ef0c3e411cbb2.320916559fc80f3403@gmail.com',
#  '3c180c298404d2e212f00ee9_1a9f22@yahoo.com',
#  'adf2239f8a6f5d_0fec3d@yahoo.com',
#  'fe387d39005a3cf49e438a709eff6cd45d5a3c@protonmail.com',
#  'a47116060c40a52995de4f3f0b99fba0b1b42c70c99b@protonmail.com',
#  '2d3d7a12d4.22de51d613c02b20105fd9@hotmail.com',
#  'e2bfe007329161b3.c84931530c6107@protonmail.com',
#  '6d4fd5b46abfe502e647_1939bb27@gmail.com',
#  '35fd9d40159c6979c9_7136@hotmail.com',
#  '30e801e20b07433449607652ddbe1b3f55b48e@gmail.com',
#  'fee189e56e88548a3646.5f473f@hotmail.com',
#  '58989071433c3478aa747d.876f28c924d8032751b33f45@hotmail.com',
#  '511bc7512abedc20_21fe9d5b0e@protonmail.com',
#  'e320bc3eebed5c4623c8.02e022@hotmail.com',
#  '4aaa80459613.d46b194f0cdb1a@hotmail.com',
#  '05d4625c05bb22a0.f36ad0b829608036@yahoo.com',
#  'f1e9a7.87f9741b9e13cf6d6f@protonmail.com',
#  '58250bd357b0623a3f.5285c662e33bcf7c@protonmail.com',
#  'fa3613701d3237e1d8717bd04cfb@hotmail.com',
#  '635fc4fa67653f1cd326b7280a8e80dd@hotmail.com',
#  'afb6b2916c1bf9cf2dd26562aea4fe@gmail.com',
#  'd14bad666884_560a46373dc1@yahoo.com',
#  'fe5e24ee6683cd26ab83135f31af29031f@protonmail.com',
#  '13e9fd17922828.a843bf@protonmail.com',
#  'a2f10c446722b196b38573ccedb52eddc9ea8f3da8@gmail.com',
#  'eb76c47eac00a6.a5c4dd990c9b3e6fa031cf72@protonmail.com',
#  '7fb57947d5ed6189f98850e1018206@gmail.com',
#  '4ce3503976cb2bf1320e.2abcf5@protonmail.com',
#  '363c96_f5ee36@gmail.com',
#  '3c7145d5a0af5626a6f9ca_14f831672590@gmail.com',
#  '3234b6cf97927c672a.d6fbcf2d72041426dd2c@yahoo.com',
#  '8f68b7b8566be4fb04340da85fb96e64@hotmail.com',
#  'd03ae1ecdc.5652f5633c4a3203ec98ba3d63@protonmail.com',
#  'df245b64728d600a.d332ca07814bb969370d4e2176@gmail.com',
#  '9c65367f42c9f13b.ad156ec4374763cb56b2f79071@gmail.com',
#  '10f2cda34c8c1121212506@hotmail.com',
#  '72bc685b.17476b58582f2087cda380eb5391@hotmail.com',
#  'bc5d2264ae2b187f_77af4b2f6e1fbc3ea4d78f7e31da@yahoo.com',
#  '4ec0da6c74da_f655562c08287cc279@protonmail.com',
#  '07c32f9943b543b2dba88af3@hotmail.com',
#  '5f0eeee8.08fe7d939fbaae6fbfdc@protonmail.com',
#  '161c2429a58f13fb745de3_db60d5e0769492@yahoo.com',
#  '7030798adf9a22805aef05.8c70589085b47dfa0cec151997d6@protonmail.com',
#  '3387c4.f47984de981e7198a3@hotmail.com',
#  '5fd6b7052c9671d3ec6eff619ba59c6af3@gmail.com',
#  '4942522d966cd89502612e4e92ac46e0c014ab62@protonmail.com',
#  'ab35f45e1f484e10c25c.8b917e9edebb01725e552f@protonmail.com',
#  'fd1bc17411fd485a.ae8c@gmail.com',
#  '9c96a0df_9119f3@protonmail.com',
#  '8a349a5c73766264.0337e016a497defc5f@gmail.com',
#  'b6c6976435_d3e59339785e23c1f17b2c6e@yahoo.com',
#  '85abc3fc7193bd0f012d@gmail.com',
#  'f6c923.8a6a89@protonmail.com',
#  '446827170ef836ccb50651_de63@hotmail.com',
#  'ecadd97c4e22775b7e5da48c1c7d5d@gmail.com',
#  '87b1c7b46adf7674696f45001c71cdca96a29d@protonmail.com',
#  '0c12ef9d15451a8213ab50dbf1@protonmail.com',
#  'c4b4393e47616b41d8_48f0636bef23f6b90045e0a6eb@protonmail.com',
#  '8e1a970dd88c036ff881a4ce4a1c@hotmail.com',
#  'caf2ec9c48b0_19ad532aa36a20@hotmail.com',
#  '9f887fffd5b9265b3b69907ba0de717295810260@gmail.com',
#  'f5698725a3761bd61b256ee0_d1b874256ffc934c@hotmail.com',
#  '6c5f487f71986764921cbfdc53@yahoo.com',
#  '146be8d9d4363f91_3f4bc73974a203e0@protonmail.com',
#  '1e331172f5e544be65_82ebccbb435441@yahoo.com',
#  '9697a5c4_399ca03e47ddf12dd163f270b4@yahoo.com',
#  'cc23d6.534292699e206566f7f1c938@gmail.com',
#  '52d23e4d89b102_a8782779a5@protonmail.com',
#  'f24e623bec6c0ac2fcdbc0e4.5eeef3ac1e@protonmail.com',
#  '80969be029a96448e58d2b4a.66e41c782d2c81@gmail.com',
#  '921616cd27_6f5bb0@yahoo.com',
#  'bd0f3731cf954bb12b.b5794ad9608c607f@protonmail.com',
#  'f6150475562aa7dd24b1da@hotmail.com',
#  '5d00715ab69f0fbbf4.67e841@hotmail.com',
#  '7d6188.7d93@yahoo.com',
#  '6811a485c8_019951a6d516c4ed88687b59@yahoo.com',
#  '1bc7e12d9176_455770a6@gmail.com',
#  'e0114ead71_97eefa50@gmail.com',
#  'c75a92e6c918bbc0a3_28e23e81d63989@gmail.com',
#  '35fc8d71065bbe_2b30@hotmail.com',
#  '9fcc7a961241c85886c9.2e6b8d1c44127c0c09@gmail.com',
#  'd76a7c5dfa423699931e8fb7847500c074f903aa@yahoo.com',
#  '16ff45f96551d50ace@gmail.com',
#  'fa9431b3_90cd2f4ac76c395e891db10bcd@gmail.com',
#  '04656f1f8ad3.76223cd4bc20ff4f43eec694@gmail.com',
#  '522215dfa4520eacb87f78@gmail.com',
#  'ebefcb72bc6269.4645bb992a@protonmail.com',
#  'f6430a223a80cd5e_b6bd9b10aa1fdd3ef83a67@hotmail.com',
#  'c36e7daa76efb139bb@hotmail.com',
#  'a402f9ccbd_cf83152a830f01ae9de8@gmail.com',
#  'fa1168bb6f2d9a034168d0ea48c1cf@gmail.com',
#  '674423dea9.358f4fc3@protonmail.com',
#  '839905cc012c7abbfe9862a1.0c7b3094@hotmail.com',
#  '3ba5136c03b079.638ff7a152223dd3cf36bbcd27@protonmail.com',
#  '3b4c3bee16cb0248693c9b98055760ff9eb33705@protonmail.com',
#  '208abf257eea0485f66e22480c267fc9237690c1ad@yahoo.com',
#  '8d89bf00697a7bcc700cba11_7caa4a23aaa34886@yahoo.com',
#  'd4ac2495_3e32bb0647b2bf98ef3d96@gmail.com',
#  'dd0a1707.73d0d74a0e3c@protonmail.com',
#  '11d5170d979d7acc.3f1914f036f614d4@yahoo.com',
#  'f75b3c02b828ffeaaf.b4f2e0e5c77a97cf@protonmail.com',
#  '9c99f0d1478126_d0f4a300@gmail.com',
#  '096706d1cbdd3f0233bf97391814@protonmail.com',
#  '9a5649183e16.101b45c83c@yahoo.com',
#  '84d4aa13d52401dcd2dcaed7f78f9371240c0237@gmail.com',
#  '01bb71ebc70823_918646b8d1db93d3d0139b@protonmail.com',
#  '898a6ab17435db90_864382d460@protonmail.com',
#  'cf3cb632f8_6f243423b8@yahoo.com',
#  '83c21df9f87751e76f81.36b04cc013f08db0421b@gmail.com',
#  '804cd882175e7dbd_5a2f@protonmail.com',
#  'fb311caabf73c82cdfdf5d_daf610@hotmail.com',
#  'e74e6300b93d5f20d091f724c768@yahoo.com',
#  'e68bbdc9cb4f7237.fa55fde08bf7@yahoo.com',
#  'e5b1f3f52ae95879471b_35387523593f49d87d@protonmail.com',
#  'ee09163d38a037a74d88db.09661ece3cfa@hotmail.com',
#  '68d7a63a17183eed_f20c3f7794a22f9fddd13af5@hotmail.com',
#  '294609de4d9c80214501164f_e5f8946fce08e25a53cb@protonmail.com',
#  '6b8d2e3a8e173c1ff226509831f66f0f2ae12f5b0c@hotmail.com',
#  'c009109a8441d418.e1644fc162b4@hotmail.com',
#  '79cff3e6ee4f85.d3f8f54e1140797ef5248d@yahoo.com',
#  'b48813a6fe99af89f351_674acc5813577a@gmail.com',
#  '456842d85199cafee9cd92ed_d46222165aef493300c10e24e1@protonmail.com',
#  '20e22a9726238e79599c.a4c91ed2ef1cff44afec@protonmail.com',
#  '009746e340b161_d3af03bb553480c64052@protonmail.com',
#  '628b4b731a395c57.179da611635297a1@hotmail.com',
#  '289b5c_3e1fcece4bdae7@yahoo.com',
#  '0b01ec709f768e6041589494965e6a50@yahoo.com',
#  '606ee39d4ad79ddc_de2a1572@protonmail.com',
#  'cbd7570d8b.a90797@yahoo.com',
#  'dedce369.ebf2b2acd99d1d877e2d6845aa43@protonmail.com',
#  'c6f43f1fe4a1ff623caf@protonmail.com',
#  '9cb70600050172f512f3aa.ecf4@hotmail.com',
#  'c3e4ec3531a16a7cd6556919ae96b57a1c96@hotmail.com',
#  '1d4a925a.457087a2@protonmail.com',
#  '33ab48cdd040c1.ddd8a362808434837724ca@hotmail.com',
#  'bd19cf68b7_e51209e8ad457c7b4bde596573@gmail.com',
#  '9fea69123907d210.2cdf91470aa3fb9ae1@gmail.com',
#  '6ced47e90c86eb1de270df02c3@hotmail.com',
#  '5b78d8e7e4_6f3befe23b80@yahoo.com',
#  '4d2ae73094a627bc3beb8919e4ba@yahoo.com',
#  'c5628d.1a25212910b04efc3b@protonmail.com',
#  '73275ae613b483_bc73@hotmail.com',
#  '4684ad3dc3a29592fc6e256e226f706dd0389cb51607@yahoo.com',
#  'd398da1d700ee7d928_f2e1550bd30a@yahoo.com',
#  '550c6a594f1d9779.357a7a71a72b0dff@protonmail.com',
#  '2a6cf3f5993be9453eb31000f4e615e297ff9beb@protonmail.com',
#  '18668e1b0903b0ce6fa9_41aea6589c2913ee7040f6c0c7@yahoo.com',
#  '0fad86_f1ba9397581c40b682@protonmail.com',
#  '0408cc08049ccea02949.7cc3179a792b@hotmail.com',
#  'c759e10b68a9d2ac9e83e2e6@protonmail.com',
#  '353b8fff.5558edeb84dba4@protonmail.com',
#  '0b5733d7460c3df9_f101975454d58ee8@protonmail.com',
#  '59f21b361081d34b3bee5fa663f9a0@yahoo.com',
#  '57888ebf6b12b0.adde@yahoo.com',
#  '7606ea3c0cc938dba472@protonmail.com',
#  '66ea0609844cab0d621183.ed969a038ed299320c@gmail.com',
#  'c7817d7a68912186b4dcf3a3414b82b6099a2ecf998ec3c692@gmail.com',
#  '00702756b22cdae1_cc743021bc0e2c7a41@gmail.com',
#  'c0277e4165cbe3da2276_70ea859bb40fdbf9@yahoo.com',
#  '3d108d57.40814ace6feb55529359201e1a24@yahoo.com',
#  '7a322044020db0710da9.2256d8e6c5d6@yahoo.com',
#  '95f86fcdddf426_bf0c33da929c@protonmail.com',
#  'e0fb91295f62b9_1d1e99fb3a466bd3d4444d0645@hotmail.com',
#  'e7fad7a4c79cb620bf4b60ef_4fd7396bf858@protonmail.com',
#  'afce1a1dd9.3b6e59d655b70f@protonmail.com',
#  '34f0bbba6945b9795e_4e2115528a@yahoo.com',
#  '8065135f80850e3886417e2c45d0f62abf@protonmail.com',
#  '82db4ca1411dd152079738e579721c16301bf0ba60@protonmail.com',
#  '2e8f39656cf858fd_e297f3e56b346aca45769a@protonmail.com',
#  'b6675c_3466e55c4b9695204de43e89e2@hotmail.com',
#  '3c0c1b500ef461638e6e216ad303f1ae7322@protonmail.com',
#  '53abacc42c833b3ceafda9506f5f52ba999f739b@protonmail.com',
#  '81521051e3edeb14507f0a19_27eff62a37@hotmail.com',
#  '2c733d5feb689adc.45c4fd72@yahoo.com',
#  '2662e924ae4d5422ab53bf113184c01b@protonmail.com',
#  '12ded67bd5e23730c9f6c9_d453b3@protonmail.com',
#  '54b3a1d7_26b9257035558be2cabb8442@yahoo.com',
#  'beecb9c21befb92d56262800d0eba109@yahoo.com',
#  '3fa10cc1d66a57.594258@yahoo.com',
#  'fa7ee8f65047e7af_db25e936539868273a@gmail.com',
#  'fa3e780dd568abb5575b53.2687c6c6ce93@gmail.com',
#  '90974c04cb0b800736ad18d9b5a57bac@protonmail.com',
#  '6b4f670a_a93b5f754f2b61fa@hotmail.com',
#  'aed1e5bcce024c6c021230.f31f104111@hotmail.com',
#  'b8b6aa546f317fcdac3ff4b1d0d28f284c33b88a@hotmail.com',
#  '3b094c97f1b1f1ff3b412544a050f3b976b42f@hotmail.com',
#  '2c6ec45bcb7f0bb5eff3d9.269b2f55009744d75f172c@yahoo.com',
#  'f2917acae1f6df53269af8@gmail.com',
#  '2b316b823ac0d42afcca19.805bf60972fc3a7cd970b0ed@gmail.com',
#  'a69a43eb.cc2b2308d8ede7d5062f@hotmail.com',
#  '99ea268575988b40@hotmail.com',
#  '0eba837197c89661d83766d1729d66@yahoo.com',
#  '361b7f860b4040ce29a69a@protonmail.com',
#  '17c0d8b6_de1ead5fd840@yahoo.com',
#  '1539f9ad43bdc6cace50_80a1bacd692cb125787b64c7d976@gmail.com',
#  '1a62ea55a2678e_1eddb328@protonmail.com',
#  'a26c3351325c_c4a7ab7b3b540f6b@hotmail.com',
#  'fd2841.01426cc269c99a8abe1a@hotmail.com',
#  '6e0ef1ac3d765c94b387684a_1e53d818e634@yahoo.com',
#  '2de1858bb20c418b9fad37505e6c05ea@protonmail.com',
#  'c514523bfe63d0015937edba9998014c3d@hotmail.com',
#  '85b4c09fa411_98bd9911927ce9c35f@gmail.com',
#  '55bfabfe8cc28781f1347201e9d0a0a20a92@yahoo.com',
#  '99017302bc319e_c0afd270fe9d627f6f@gmail.com',
#  'b30b5c5db92d.04a064ae7223@yahoo.com',
#  '7b20bb994213.ee878b3d1054@hotmail.com',
#  'dd51018008675df5c6@yahoo.com',
#  'fd30ddc318f1@protonmail.com',
#  'ab45522a2a81f100d502_1cb7@yahoo.com',
#  '22ab2b81146af321633e2d.83c80a881a854f455deb90@hotmail.com',
#  '83190cee5047dd0f_28873723afd8b2fa@hotmail.com',
#  '77c4906d7dce820f64@gmail.com',
#  'eef8bc0e87_7520e6bbe6913f94@yahoo.com',
#  '8d9f0156f6be450352057f13f27be9@hotmail.com',
#  '9c5e6492ebb9b70eb7b839.f1a60a158e920b@yahoo.com',
#  '690f2387b3_9aee8a0b4067e798ac@protonmail.com',
#  '7cd24afed98545d1077c0022.20fa97e5e62136b82c8c6c8799@hotmail.com',
#  '71abe2cbe9460497.7db5eb9597b2c862c61e6d@protonmail.com',
#  '6816da9efc7ab45125.b899de5ae713ddd4568104@gmail.com',
#  'e0078bd1894172b68ead_d9ad63afbf16522f9d1975f3@yahoo.com',
#  'a50ad28851b40c5137805cc38474c1@protonmail.com',
#  '37bfdeca.ccc354e481a587eb2ac5af@protonmail.com',
#  'd8eb0544.2cf2606d2f@yahoo.com',
#  'ebc4b237.68de39b31b4c28736346c4@yahoo.com',
#  '55716aa526896b59256cb451.b45daf171cf8350ff70443139d@gmail.com',
#  '065f2647b8a3b57f17ea81.b219d9c4fd4446c3a3fbabdba7@yahoo.com',
#  '6af48fccb3_640e@hotmail.com',
#  '266ce5ea13cc589f@protonmail.com',
#  '28545384f2286abc905c.e2fbc4@yahoo.com',
#  '5fc2b12578ba05_55addc1b03d1f2823d61c594d1a0@yahoo.com',
#  '1dc2415653a7f6ea9912315959cff465@gmail.com',
#  'cf990802f0690e90a7aa_c0ed22fa98365344@protonmail.com',
#  '9226f1da11.3d719162@hotmail.com',
#  'f9c6b1407381_7776c626db23@protonmail.com',
#  'aec4ef75dcf85c78_51dc5ae919a9783774@yahoo.com',
#  'b5bf7e8f1b_7819316f316a740029@protonmail.com',
#  '39801b969923_846c77f54a1948@protonmail.com',
#  'f49f809d2de5b7_0c5acc7a83176a923afe@hotmail.com',
#  '4658263f967de073325606254d0121cb22045b@yahoo.com',
#  '0f137d0373c01b95bd245597df@hotmail.com',
#  '821ef1eb3f3d48db47@yahoo.com',
#  '28aa1591.88c019b2c9f08e@gmail.com',
#  '9fb02626.2ad185@protonmail.com',
#  '771ccde54482217160a8.6743eca4836ae210a474@hotmail.com',
#  '046117e5d6dcd29cc28488fb0d18bd@protonmail.com',
#  'a826980e3a4304484e34.5986adf7b45f@protonmail.com',
#  'a082cbe512fc3fa2e264@gmail.com',
#  '14ac3f2d9781e1_1959f38a9e126d8bd4@protonmail.com',
#  '1b03c0a14341_f8637c725035fd6e0d7b@gmail.com',
#  '10336199.f48ef1da23b5130b@protonmail.com',
#  'de7d0502a73ff07d459d23a6.5ca836930b8147@hotmail.com',
#  '2002be_9935b3d3ce58d92696c530@yahoo.com',
#  '9ceb7b086527aa312a95e46e.296656@hotmail.com',
#  '8259f77e_56a8f17cc5ed6a2a@hotmail.com',
#  '82699b4d6c34104767.80ea960f79aeaef370b528c88776@hotmail.com',
#  '289ed26b19.069f2899e8e168@hotmail.com',
#  '675f82ba97768eb2.df16d60b80@gmail.com',
#  'bdc5bdd72dff83ec531c0eea_34179af302b5043b40d4@protonmail.com',
#  '296c34d6ac0810eef37b6b607e6888b1@gmail.com',
#  'a21ffdc69d615499_e5c4e08c1d4f3767@protonmail.com',
#  'a5aaa6e6_7dd81b@gmail.com',
#  '6c0ac5.b91429c64cb05c@gmail.com',
#  '9ea84690d7aa43e041dd.72a61f@yahoo.com',
#  '4138313759a0521ef2f728753117194e40319d10@hotmail.com',
#  'ad526b80.88f47b295f2f6244cf6c18@gmail.com',
#  'b87f962ffca939bba1_895a01914a1db2fc0d3b47@yahoo.com',
#  '88fb89_28bcec8c9b084f47dfbb35@yahoo.com',
#  'a72c13a53f447e60d9f18595.fc902a12@yahoo.com',
#  '04bd9e9c7322b7b0@yahoo.com',
#  'c30f996904354a6c3c42400307bc2be638@yahoo.com',
#  'b57c82ba936d13a01077b3ecd5044de959cabeaedc@yahoo.com',
#  '949ecc50b660c5_2d28@yahoo.com',
#  'ceaa91adfd08d29f5b8aa23d3fae9679b03c@protonmail.com',
#  'afa103ad5f9ee11d744e68d022b1e8ea534be04afcec@yahoo.com',
#  '90e931.035e@gmail.com',
#  '5c5d1d6b93bc28136c856b.0760b284d45568656aae5e0e1d24@yahoo.com',
#  '7aac328b1014ad@gmail.com',
#  '951673_4607@hotmail.com',
#  '3b0641b5f830074a9c_55948f3e2ecb@protonmail.com',
#  '7840f96bd68404_df4a1f65865322df98@gmail.com',
#  '0e9164a68d626359a49748.4385ed75c6d312f7@protonmail.com',
#  '863e6e4c4753_531e1c920856a87f1c5c85b43474@hotmail.com',
#  '6f65b2c909.2c6a45abaeedee41d4fd@gmail.com',
#  '16e04148d4d0f1e8d72d3622605425379da608cf51e2c2@hotmail.com',
#  '0e485fa54e5f3f_5e42747efc5ad2874a@hotmail.com',
#  '0716bfdf.d44d87fe@protonmail.com',
#  '01282f45_4410@protonmail.com',
#  'ce6205293f_30f1f31e80201272@hotmail.com',
#  '100c93a3f8_52034502bc@yahoo.com',
#  '2249a2b7ac900bab4758da78.d22ce941a7e95842f579bedc8c@gmail.com',
#  'eb475a3eaad4.d52820c7@hotmail.com',
#  '34d74455d61db750756ade82becd6fe28e29ed56@yahoo.com',
#  'cfb860687627978caea93c@yahoo.com',
#  '083a43d128_91250293a48c9a81ce394c9beadd@protonmail.com',
#  'd66c406b427d973f45fee3500384eeae496e@yahoo.com',
#  '3f9ad93def_307c2a50@yahoo.com',
#  'c8e61c8243bfc2686e835fd9_9b8f6dfdc9@gmail.com',
#  '30f8c3d1f7fc38e1c78bad23ec2648@gmail.com',
#  'd57d042726b1ad1632103d1b81@yahoo.com',
#  '04d77367c5c70eaf.884d74af6f1f@protonmail.com',
#  '99cbbf94279dc5ad_84333db7@gmail.com',
#  '4d2047f7d55ae7.011b11ce184535bd@yahoo.com',
#  ...]

# %%
students = [{"name":"Alice","course":"BSME","strand":"STEM"},
 {"name":"Bob","course":"BSME","strand":""},
 {"name":"Carol","course":"BSITE","strand":""},
 {"name":"Charlie","course":"BSITE","strand":""},
 {"name":"Chuck","course":"BSLM","strand":""},
 {"name":"Charlie","course":"BSME","strand":""},
 {"name":"Dave","course":"BSMGTH","strand":"GAS"},
 {"name":"Eve","course":"BSMGT","strand":""},
 {"name":"Frank","course":"BSITE","strand":"Arts and Design"},
 ]
# Dump List
listdf = pd.DataFrame(students)
listdf
# Out:
#       name  course           strand
# 0    Alice    BSME             STEM
# 1      Bob    BSME
# 2    Carol   BSITE
# 3  Charlie   BSITE
# 4    Chuck    BSLM
# 5  Charlie    BSME
# 6     Dave  BSMGTH              GAS
# 7      Eve   BSMGT
# 8    Frank   BSITE  Arts and Design

# %%
new = listdf.loc[:, 'strand'] == 'IB'
new
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# Name: strand, dtype: bool

# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html

# %% [markdown]
# ### 2.2
#
# Your client wants you to generate a comprehensive list of the identities present in their scattered data. Their specifications are as follows:
# 1. Use the cleaned data from 2.1 as your data source.
# 2. Use the emails as the indicator of a unique identity.
# 3. Sort the final file by the email in alphabetical order.
#
# Save the cleaned data sets as `./output/merged-identities.csv`.
#
# Do not include the dataframe index in the output csv.

# %%
# CODE CELL
import pandas as pd

# CODE START

# CODE END
